# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library  
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | saint-georges
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | ternate
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | pudozh
# Processing Record 12 of Set 1 | boddam
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | lixourion
# Processing Record 16 of Set 1 | alofi
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | awjilah
# Processing Record 20 of Set 1 | gizo
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | rockport
# Processing Record 24 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | sitka
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | mormugao
# Processing Record 29 of Set 1 | nueva loja
# Processing Record 30 of Set 1 | hofn
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | palmer
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | fulitun
# City not found. Skipping...
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | koslan
# Processing Record 41 of Set 1 | thomasville
# Processing Record 42 of Set 1 | zeya
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | porto velho
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | faya
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | la asuncion
# Processing Record 50 of Set 1 | ibanda
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | kupang
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | guerrero negro
# Processing Record 11 of Set 2 | flinders
# Processing Record 12 of Set 2 | yatou
# Processing Record 13 of Set 2 | eugene
# Processing Record 14 of Set 2 | coracora
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | port hardy
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | imbituba
# Processing Record 21 of Set 2 | semey
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | khash
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | lucapa
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | dunedin
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | la paz
# Processing Record 32 of Set 2 | teya
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | betera
# Processing Record 35 of Set 2 | kaeo
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | burica
# City not found. Skipping...
# Processing Record 39 of Set 2 | almeirim
# Processing Record 40 of Set 2 | leningradskiy
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | ballina
# Processing Record 43 of Set 2 | kommunar
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 2 | nicoya
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | tornio
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | tucuman
# Processing Record 3 of Set 3 | uglegorsk
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | bardiyah
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | tenenkou
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | tessalit
# Processing Record 10 of Set 3 | lovington
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | mahibadhoo
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | menzelinsk
# Processing Record 16 of Set 3 | okato
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | burgeo
# Processing Record 19 of Set 3 | satinka
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | ponnampet
# Processing Record 22 of Set 3 | coahuayana
# Processing Record 23 of Set 3 | tilichiki
# Processing Record 24 of Set 3 | adrar
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | tanout
# Processing Record 27 of Set 3 | samarai
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | maningrida
# Processing Record 30 of Set 3 | aliverion
# City not found. Skipping...
# Processing Record 31 of Set 3 | pedernales
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | ugoofaaru
# Processing Record 34 of Set 3 | quthing
# Processing Record 35 of Set 3 | moron
# Processing Record 36 of Set 3 | kruisfontein
# Processing Record 37 of Set 3 | mount pleasant
# Processing Record 38 of Set 3 | doha
# Processing Record 39 of Set 3 | siilinjarvi
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | pokrovsk
# Processing Record 46 of Set 3 | aloleng
# Processing Record 47 of Set 3 | rubtsovsk
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | semenivka
# Processing Record 50 of Set 3 | ahipara
# Processing Record 1 of Set 4 | walvis bay
# Processing Record 2 of Set 4 | high prairie
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | saint-augustin
# Processing Record 6 of Set 4 | santa maria
# Processing Record 7 of Set 4 | miraflores
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | asau
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | vieste
# Processing Record 15 of Set 4 | challapata
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | kosikha
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | marawi
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | mandalgovi
# Processing Record 24 of Set 4 | papenburg
# Processing Record 25 of Set 4 | kulhudhuffushi
# Processing Record 26 of Set 4 | aksarka
# Processing Record 27 of Set 4 | khani
# Processing Record 28 of Set 4 | tay ninh
# Processing Record 29 of Set 4 | puerto montt
# Processing Record 30 of Set 4 | high level
# Processing Record 31 of Set 4 | cheremukhovo
# Processing Record 32 of Set 4 | conde
# Processing Record 33 of Set 4 | zhigansk
# Processing Record 34 of Set 4 | ulladulla
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | gat
# Processing Record 38 of Set 4 | mbigou
# Processing Record 39 of Set 4 | port blair
# Processing Record 40 of Set 4 | souillac
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | hervey bay
# Processing Record 46 of Set 4 | turukhansk
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | masumbwe
# Processing Record 50 of Set 4 | matameye
# City not found. Skipping...
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | luena
# Processing Record 3 of Set 5 | thessalon
# Processing Record 4 of Set 5 | rio gallegos
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | bluff
# Processing Record 9 of Set 5 | lapua
# Processing Record 10 of Set 5 | abha
# Processing Record 11 of Set 5 | nizhneudinsk
# Processing Record 12 of Set 5 | jingdezhen
# Processing Record 13 of Set 5 | lucatan
# City not found. Skipping...
# Processing Record 14 of Set 5 | baruun-urt
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | katobu
# Processing Record 17 of Set 5 | airai
# Processing Record 18 of Set 5 | mapiripan
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | bathsheba
# Processing Record 21 of Set 5 | omboue
# Processing Record 22 of Set 5 | praia da vitoria
# Processing Record 23 of Set 5 | buala
# Processing Record 24 of Set 5 | chake chake
# Processing Record 25 of Set 5 | wanning
# Processing Record 26 of Set 5 | mancora
# Processing Record 27 of Set 5 | ayagoz
# Processing Record 28 of Set 5 | auki
# Processing Record 29 of Set 5 | kavieng
# Processing Record 30 of Set 5 | ondangwa
# Processing Record 31 of Set 5 | wenling
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | owando
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | harper
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | san roque
# Processing Record 38 of Set 5 | linxia
# Processing Record 39 of Set 5 | kayerkan
# Processing Record 40 of Set 5 | san felipe
# Processing Record 41 of Set 5 | vao
# Processing Record 42 of Set 5 | roald
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | fort frances
# Processing Record 45 of Set 5 | iwaki
# Processing Record 46 of Set 5 | yanam
# Processing Record 47 of Set 5 | mayo
# Processing Record 48 of Set 5 | sabzevar
# Processing Record 49 of Set 5 | mogadishu
# Processing Record 50 of Set 5 | benghazi
# Processing Record 1 of Set 6 | baicheng
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | poum
# Processing Record 4 of Set 6 | mount darwin
# Processing Record 5 of Set 6 | pevek
# Processing Record 6 of Set 6 | krasnaya zarya
# Processing Record 7 of Set 6 | kenai
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | mahanoro
# Processing Record 10 of Set 6 | moerai
# Processing Record 11 of Set 6 | mangrol
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | viransehir
# Processing Record 14 of Set 6 | coquimbo
# Processing Record 15 of Set 6 | manaus
# Processing Record 16 of Set 6 | mayumba
# Processing Record 17 of Set 6 | ancud
# Processing Record 18 of Set 6 | ribeirao branco
# Processing Record 19 of Set 6 | lins
# Processing Record 20 of Set 6 | kalemie
# Processing Record 21 of Set 6 | botwood
# Processing Record 22 of Set 6 | xinyu
# Processing Record 23 of Set 6 | bereda
# Processing Record 24 of Set 6 | ambilobe
# Processing Record 25 of Set 6 | pangkalanbuun
# Processing Record 26 of Set 6 | pasinler
# Processing Record 27 of Set 6 | geraldton
# Processing Record 28 of Set 6 | brae
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | santa cruz
# Processing Record 32 of Set 6 | kropotkin
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | pospelikha
# Processing Record 35 of Set 6 | fortuna
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | anadyr
# Processing Record 38 of Set 6 | van buren
# Processing Record 39 of Set 6 | camargo
# Processing Record 40 of Set 6 | berlevag
# Processing Record 41 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 6 | gorom-gorom
# Processing Record 43 of Set 6 | road town
# Processing Record 44 of Set 6 | rundu
# Processing Record 45 of Set 6 | bacalar
# Processing Record 46 of Set 6 | northam
# Processing Record 47 of Set 6 | shubarshi
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | necochea
# Processing Record 50 of Set 6 | half moon bay
# Processing Record 1 of Set 7 | dickinson
# Processing Record 2 of Set 7 | dicabisagan
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | cayenne
# Processing Record 5 of Set 7 | tangier
# Processing Record 6 of Set 7 | naze
# Processing Record 7 of Set 7 | atbasar
# Processing Record 8 of Set 7 | kochi
# Processing Record 9 of Set 7 | krasnoselkup
# Processing Record 10 of Set 7 | yuzhno-kurilsk
# Processing Record 11 of Set 7 | lensk
# Processing Record 12 of Set 7 | mbarara
# Processing Record 13 of Set 7 | saint-joseph
# Processing Record 14 of Set 7 | manali
# Processing Record 15 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 7 | gidole
# Processing Record 17 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 7 | celestun
# Processing Record 19 of Set 7 | bafilo
# Processing Record 20 of Set 7 | ayan
# Processing Record 21 of Set 7 | qarqin
# Processing Record 22 of Set 7 | teknaf
# Processing Record 23 of Set 7 | agadir
# Processing Record 24 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 7 | synya
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 7 | kiruna
# Processing Record 29 of Set 7 | katsuura
# Processing Record 30 of Set 7 | mawlaik
# Processing Record 31 of Set 7 | lamesa
# Processing Record 32 of Set 7 | seoul
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | fuente palmera
# Processing Record 35 of Set 7 | ambovombe
# Processing Record 36 of Set 7 | santo domingo de guzman
# Processing Record 37 of Set 7 | merauke
# Processing Record 38 of Set 7 | vanavara
# Processing Record 39 of Set 7 | krasnokamensk
# Processing Record 40 of Set 7 | botou
# Processing Record 41 of Set 7 | banjar
# Processing Record 42 of Set 7 | nyandoma
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | marrakesh
# Processing Record 46 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 7 | yumen
# Processing Record 49 of Set 7 | douentza
# Processing Record 50 of Set 7 | tazovskiy
# Processing Record 1 of Set 8 | macusani
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | inhambane
# Processing Record 5 of Set 8 | thompson
# Processing Record 6 of Set 8 | kelowna
# Processing Record 7 of Set 8 | paranga
# Processing Record 8 of Set 8 | klaebu
# Processing Record 9 of Set 8 | eureka
# Processing Record 10 of Set 8 | port macquarie
# Processing Record 11 of Set 8 | ajdabiya
# Processing Record 12 of Set 8 | san jose
# Processing Record 13 of Set 8 | ginir
# Processing Record 14 of Set 8 | tecoanapa
# Processing Record 15 of Set 8 | yudong
# Processing Record 16 of Set 8 | hailar
# Processing Record 17 of Set 8 | porto novo
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | menongue
# Processing Record 20 of Set 8 | iowa city
# Processing Record 21 of Set 8 | gondar
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | kapit
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | lashio
# Processing Record 26 of Set 8 | bytow
# Processing Record 27 of Set 8 | anse-bertrand
# Processing Record 28 of Set 8 | pailitas
# Processing Record 29 of Set 8 | brainerd
# Processing Record 30 of Set 8 | alugan
# Processing Record 31 of Set 8 | tsotilion
# Processing Record 32 of Set 8 | moose factory
# Processing Record 33 of Set 8 | veydelevka
# Processing Record 34 of Set 8 | matozinhos
# Processing Record 35 of Set 8 | soure
# Processing Record 36 of Set 8 | selenginsk
# Processing Record 37 of Set 8 | chapeco
# Processing Record 38 of Set 8 | mitsamiouli
# Processing Record 39 of Set 8 | manado
# Processing Record 40 of Set 8 | xining
# Processing Record 41 of Set 8 | caravelas
# Processing Record 42 of Set 8 | aswan
# Processing Record 43 of Set 8 | barcelos
# Processing Record 44 of Set 8 | shingu
# Processing Record 45 of Set 8 | ivangorod
# Processing Record 46 of Set 8 | wodonga
# Processing Record 47 of Set 8 | new iberia
# Processing Record 48 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 8 | wapi pathum
# Processing Record 50 of Set 8 | padang
# Processing Record 1 of Set 9 | inirida
# Processing Record 2 of Set 9 | la romana
# Processing Record 3 of Set 9 | varzea da palma
# Processing Record 4 of Set 9 | sidi ali
# Processing Record 5 of Set 9 | smithers
# Processing Record 6 of Set 9 | dubbo
# Processing Record 7 of Set 9 | lahaina
# Processing Record 8 of Set 9 | oyon
# Processing Record 9 of Set 9 | qorveh
# Processing Record 10 of Set 9 | maloy
# Processing Record 11 of Set 9 | mopipi
# Processing Record 12 of Set 9 | launceston
# Processing Record 13 of Set 9 | egvekinot
# Processing Record 14 of Set 9 | dali
# Processing Record 15 of Set 9 | valdivia
# Processing Record 16 of Set 9 | sakakah
# Processing Record 17 of Set 9 | slave lake
# Processing Record 18 of Set 9 | netivot
# Processing Record 19 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | benito juarez
# Processing Record 21 of Set 9 | chicama
# Processing Record 22 of Set 9 | tanggu
# Processing Record 23 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 9 | chumikan
# Processing Record 25 of Set 9 | velizh
# Processing Record 26 of Set 9 | provideniya
# Processing Record 27 of Set 9 | sioux lookout
# Processing Record 28 of Set 9 | kirakira
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | boa vista
# Processing Record 32 of Set 9 | moshi
# Processing Record 33 of Set 9 | batagay
# Processing Record 34 of Set 9 | tela
# Processing Record 35 of Set 9 | olinda
# Processing Record 36 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 9 | montelibano
# Processing Record 38 of Set 9 | dongsheng
# Processing Record 39 of Set 9 | meadow lake
# Processing Record 40 of Set 9 | jieshi
# Processing Record 41 of Set 9 | mnogovershinnyy
# Processing Record 42 of Set 9 | portage
# Processing Record 43 of Set 9 | urucurituba
# Processing Record 44 of Set 9 | norman wells
# Processing Record 45 of Set 9 | oro valley
# Processing Record 46 of Set 9 | saraland
# Processing Record 47 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 9 | mastic beach
# Processing Record 49 of Set 9 | innisfail
# Processing Record 50 of Set 9 | key west
# Processing Record 1 of Set 10 | kuala terengganu
# Processing Record 2 of Set 10 | birnin kebbi
# Processing Record 3 of Set 10 | belaya gora
# Processing Record 4 of Set 10 | bulgan
# Processing Record 5 of Set 10 | colac
# Processing Record 6 of Set 10 | haverfordwest
# Processing Record 7 of Set 10 | vagur
# Processing Record 8 of Set 10 | inta
# Processing Record 9 of Set 10 | puerto madero
# Processing Record 10 of Set 10 | vvedenka
# Processing Record 11 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 10 | marsh harbour
# Processing Record 13 of Set 10 | neuquen
# Processing Record 14 of Set 10 | coro
# Processing Record 15 of Set 10 | bolnisi
# Processing Record 16 of Set 10 | zhangjiakou
# Processing Record 17 of Set 10 | diamantino
# Processing Record 18 of Set 10 | warmbad
# Processing Record 19 of Set 10 | teguldet
# Processing Record 20 of Set 10 | kahului
# Processing Record 21 of Set 10 | hongan
# City not found. Skipping...
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | vikarabad
# Processing Record 24 of Set 10 | muli
# Processing Record 25 of Set 10 | olafsvik
# Processing Record 26 of Set 10 | mukhen
# Processing Record 27 of Set 10 | praia
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | banepa
# Processing Record 30 of Set 10 | lamu
# Processing Record 31 of Set 10 | bay-khaak
# Processing Record 32 of Set 10 | jizan
# Processing Record 33 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 10 | ghanzi
# Processing Record 35 of Set 10 | morgan city
# Processing Record 36 of Set 10 | mehamn
# Processing Record 37 of Set 10 | yamada
# Processing Record 38 of Set 10 | villa maria
# Processing Record 39 of Set 10 | fergus falls
# Processing Record 40 of Set 10 | saravan
# Processing Record 41 of Set 10 | zhangye
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | tete
# Processing Record 44 of Set 10 | looc
# Processing Record 45 of Set 10 | kloulklubed
# Processing Record 46 of Set 10 | vila velha
# Processing Record 47 of Set 10 | dabhol
# Processing Record 48 of Set 10 | kabinda
# Processing Record 49 of Set 10 | chapais
# Processing Record 50 of Set 10 | liaozhong
# Processing Record 1 of Set 11 | kismayo
# Processing Record 2 of Set 11 | vathi
# Processing Record 3 of Set 11 | komyshuvakha
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | kuito
# Processing Record 6 of Set 11 | bonfim
# Processing Record 7 of Set 11 | khorixas
# Processing Record 8 of Set 11 | te anau
# Processing Record 9 of Set 11 | mantua
# Processing Record 10 of Set 11 | cairns
# Processing Record 11 of Set 11 | jackson
# Processing Record 12 of Set 11 | alexandria
# Processing Record 13 of Set 11 | chernyshevskiy
# Processing Record 14 of Set 11 | usoke
# Processing Record 15 of Set 11 | marystown
# Processing Record 16 of Set 11 | alyangula
# Processing Record 17 of Set 11 | trairi
# Processing Record 18 of Set 11 | morwell
# Processing Record 19 of Set 11 | gladstone
# Processing Record 20 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 11 | kavaratti
# Processing Record 22 of Set 11 | shache
# Processing Record 23 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | puerto quijarro
# Processing Record 26 of Set 11 | manakara
# Processing Record 27 of Set 11 | rocha
# Processing Record 28 of Set 11 | san quintin
# Processing Record 29 of Set 11 | mecca
# Processing Record 30 of Set 11 | cikupa
# Processing Record 31 of Set 11 | valparaiso
# Processing Record 32 of Set 11 | willowmore
# Processing Record 33 of Set 11 | vysokogornyy
# Processing Record 34 of Set 11 | yasinya
# Processing Record 35 of Set 11 | talaya
# Processing Record 36 of Set 11 | mildura
# Processing Record 37 of Set 11 | djibo
# Processing Record 38 of Set 11 | mount gambier
# Processing Record 39 of Set 11 | hobyo
# Processing Record 40 of Set 11 | bondo
# Processing Record 41 of Set 11 | debica
# Processing Record 42 of Set 11 | banda aceh
# Processing Record 43 of Set 11 | kuala pilah
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | istanbul
# Processing Record 46 of Set 11 | maxixe
# Processing Record 47 of Set 11 | nemuro
# Processing Record 48 of Set 11 | tres passos
# Processing Record 49 of Set 11 | cache creek
# Processing Record 50 of Set 11 | teluk nibung
# Processing Record 1 of Set 12 | alpena
# Processing Record 2 of Set 12 | bandarbeyla
# Processing Record 3 of Set 12 | vangaindrano
# Processing Record 4 of Set 12 | biak
# Processing Record 5 of Set 12 | stephenville
# Processing Record 6 of Set 12 | tigil
# Processing Record 7 of Set 12 | kathu
# Processing Record 8 of Set 12 | neu-anspach
# Processing Record 9 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 12 | monte aprazivel
# Processing Record 11 of Set 12 | oyem
# Processing Record 12 of Set 12 | cartagena
# Processing Record 13 of Set 12 | klaksvik
# Processing Record 14 of Set 12 | quatre cocos
# Processing Record 15 of Set 12 | shelburne
# Processing Record 16 of Set 12 | ambon
# Processing Record 17 of Set 12 | phan thiet
# Processing Record 18 of Set 12 | ekhabi
# Processing Record 19 of Set 12 | hun
# Processing Record 20 of Set 12 | vertou
# Processing Record 21 of Set 12 | junin
# Processing Record 22 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 12 | mudgee
# Processing Record 24 of Set 12 | anchorage
# Processing Record 25 of Set 12 | pensacola
# Processing Record 26 of Set 12 | jumla
# Processing Record 27 of Set 12 | derazhnya
# Processing Record 28 of Set 12 | birchis
# Processing Record 29 of Set 12 | douglas
# Processing Record 30 of Set 12 | alta floresta
# Processing Record 31 of Set 12 | bonga
# Processing Record 32 of Set 12 | puqi
# Processing Record 33 of Set 12 | mvuma
# Processing Record 34 of Set 12 | wajir
# Processing Record 35 of Set 12 | gillingham
# Processing Record 36 of Set 12 | lahij
# Processing Record 37 of Set 12 | shar
# Processing Record 38 of Set 12 | gayny
# Processing Record 39 of Set 12 | pisco
# Processing Record 40 of Set 12 | bac lieu
# Processing Record 41 of Set 12 | jalu
# Processing Record 42 of Set 12 | kuva
# City not found. Skipping...
# Processing Record 43 of Set 12 | qaqortoq
# Processing Record 44 of Set 12 | los llanos de aridane
# Processing Record 45 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 12 | vestmanna
# Processing Record 47 of Set 12 | victor harbor
# Processing Record 48 of Set 12 | sangar
# Processing Record 49 of Set 12 | mackay
# Processing Record 50 of Set 12 | talnakh
# Processing Record 1 of Set 13 | shaunavon
# Processing Record 2 of Set 13 | buchanan
# Processing Record 3 of Set 13 | tateyama
# Processing Record 4 of Set 13 | aksu
# Processing Record 5 of Set 13 | acarau
# Processing Record 6 of Set 13 | nsanje
# Processing Record 7 of Set 13 | lower hutt
# Processing Record 8 of Set 13 | saint anthony
# Processing Record 9 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 10 of Set 13 | beloha
# Processing Record 11 of Set 13 | taksimo
# Processing Record 12 of Set 13 | bage
# Processing Record 13 of Set 13 | kirkwall
# Processing Record 14 of Set 13 | namatanai
# Processing Record 15 of Set 13 | durusu
# Processing Record 16 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 13 | rawson
# Processing Record 18 of Set 13 | rapla
# Processing Record 19 of Set 13 | sinfra
# Processing Record 20 of Set 13 | sovetskiy
# Processing Record 21 of Set 13 | kitui
# Processing Record 22 of Set 13 | lambarene
# Processing Record 23 of Set 13 | terme
# Processing Record 24 of Set 13 | springbok
# Processing Record 25 of Set 13 | havelock
# Processing Record 26 of Set 13 | khurja
# Processing Record 27 of Set 13 | boysun
# Processing Record 28 of Set 13 | asyut
# Processing Record 29 of Set 13 | riyadh
# Processing Record 30 of Set 13 | green valley
# Processing Record 31 of Set 13 | mbanza-ngungu
# Processing Record 32 of Set 13 | soe
# Processing Record 33 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 13 | luba
# Processing Record 35 of Set 13 | westport
# Processing Record 36 of Set 13 | terney
# Processing Record 37 of Set 13 | novoanninskiy
# Processing Record 38 of Set 13 | saint-francois
# Processing Record 39 of Set 13 | koror
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | gujrat
# Processing Record 42 of Set 13 | cristalina
# Processing Record 43 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 44 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 13 | pecos
# Processing Record 46 of Set 13 | kokopo
# Processing Record 47 of Set 13 | pilar
# Processing Record 48 of Set 13 | stolbishche
# Processing Record 49 of Set 13 | hovd
# Processing Record 50 of Set 13 | kodaikanal
# Processing Record 1 of Set 14 | ferrol
# Processing Record 2 of Set 14 | yuanping
# Processing Record 3 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 14 | zacualpan
# Processing Record 5 of Set 14 | quelimane
# Processing Record 6 of Set 14 | yenisehir
# Processing Record 7 of Set 14 | muisne
# Processing Record 8 of Set 14 | santa fe
# Processing Record 9 of Set 14 | benjamin hill
# Processing Record 10 of Set 14 | omaruru
# Processing Record 11 of Set 14 | hasaki
# Processing Record 12 of Set 14 | oranjestad
# Processing Record 13 of Set 14 | nizwa
# Processing Record 14 of Set 14 | villa carlos paz
# Processing Record 15 of Set 14 | uhlove
# Processing Record 16 of Set 14 | horta
# Processing Record 17 of Set 14 | husavik
# Processing Record 18 of Set 14 | leh
# Processing Record 19 of Set 14 | muroto
# Processing Record 20 of Set 14 | cururupu
# Processing Record 21 of Set 14 | sarangani
# Processing Record 22 of Set 14 | okmulgee
# Processing Record 23 of Set 14 | koping
# Processing Record 24 of Set 14 | dalvik
# Processing Record 25 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 14 | axim
# Processing Record 27 of Set 14 | qasigiannguit
# Processing Record 28 of Set 14 | marzuq
# Processing Record 29 of Set 14 | myitkyina
# Processing Record 30 of Set 14 | grand gaube
# Processing Record 31 of Set 14 | tulcingo
# City not found. Skipping...
# Processing Record 32 of Set 14 | nahariyya
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | sarh
# Processing Record 35 of Set 14 | tsaratanana
# Processing Record 36 of Set 14 | pozo colorado
# Processing Record 37 of Set 14 | lasa
# Processing Record 38 of Set 14 | taltal
# Processing Record 39 of Set 14 | fairbanks
# Processing Record 40 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 14 | derzhavinsk
# Processing Record 42 of Set 14 | diffa
# Processing Record 43 of Set 14 | prince george
# Processing Record 44 of Set 14 | middelkerke
# Processing Record 45 of Set 14 | pitkyaranta
# Processing Record 46 of Set 14 | willmar
# Processing Record 47 of Set 14 | krasnyy oktyabr
# Processing Record 48 of Set 14 | okhotsk
# Processing Record 49 of Set 14 | bennington
# Processing Record 50 of Set 14 | viedma
# Processing Record 1 of Set 15 | altay
# Processing Record 2 of Set 15 | saint-pierre
# Processing Record 3 of Set 15 | mahina
# Processing Record 4 of Set 15 | poya
# Processing Record 5 of Set 15 | tautira
# Processing Record 6 of Set 15 | qui nhon
# Processing Record 7 of Set 15 | boffa
# Processing Record 8 of Set 15 | simao
# Processing Record 9 of Set 15 | camalu
# Processing Record 10 of Set 15 | yomou
# Processing Record 11 of Set 15 | tezu
# Processing Record 12 of Set 15 | pangnirtung
# Processing Record 13 of Set 15 | mingshui
# Processing Record 14 of Set 15 | itaquitinga
# Processing Record 15 of Set 15 | salinopolis
# Processing Record 16 of Set 15 | tarbagatay
# Processing Record 17 of Set 15 | salinas
# Processing Record 18 of Set 15 | araouane
# Processing Record 19 of Set 15 | himora
# City not found. Skipping...
# Processing Record 20 of Set 15 | lakes entrance
# Processing Record 21 of Set 15 | starosubkhangulovo
# Processing Record 22 of Set 15 | itarema
# Processing Record 23 of Set 15 | paamiut
# Processing Record 24 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 25 of Set 15 | san ignacio
# Processing Record 26 of Set 15 | tual
# Processing Record 27 of Set 15 | bollnas
# Processing Record 28 of Set 15 | khuzdar
# Processing Record 29 of Set 15 | maragogi
# Processing Record 30 of Set 15 | tabuk
# Processing Record 31 of Set 15 | cockburn town
# Processing Record 32 of Set 15 | presidencia roque saenz pena
# Processing Record 33 of Set 15 | shaki
# Processing Record 34 of Set 15 | emerald
# Processing Record 35 of Set 15 | kazerun
# Processing Record 36 of Set 15 | hambantota
# Processing Record 37 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 15 | ketchikan
# Processing Record 39 of Set 15 | tabou
# Processing Record 40 of Set 15 | jhang
# Processing Record 41 of Set 15 | puerto colombia
# Processing Record 42 of Set 15 | noumea
# Processing Record 43 of Set 15 | bathurst
# Processing Record 44 of Set 15 | mbandaka
# Processing Record 45 of Set 15 | vargem grande
# Processing Record 46 of Set 15 | ouadda
# Processing Record 47 of Set 15 | borogontsy
# Processing Record 48 of Set 15 | rio grande
# Processing Record 49 of Set 15 | caluquembe
# Processing Record 50 of Set 15 | sambava
# Processing Record 1 of Set 16 | lorengau
# Processing Record 2 of Set 16 | mangai
# Processing Record 3 of Set 16 | waitara
# Processing Record 4 of Set 16 | yeppoon
# Processing Record 5 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 16 | elizabeth city
# Processing Record 7 of Set 16 | la spezia
# Processing Record 8 of Set 16 | lillesand
# Processing Record 9 of Set 16 | puerto ayacucho
# Processing Record 10 of Set 16 | wattegama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred -33.5906   26.8910     55.98        81           1
# 1        Rikitea -23.1203 -134.9692     67.32        77         100
# 2   Longyearbyen  78.2186   15.6401     51.64        76          75
# 3  Saint-Georges  12.0564  -61.7485     80.28        83          75
# 4   Puerto Ayora  -0.7393  -90.3518     68.56        98          73
# 5           Hilo  19.7297 -155.0900     76.28        95         100
# 6        Ternate   0.8000  127.4000     79.09        85         100
# 7      Jamestown  42.0970  -79.2353     60.39        86           0
# 8        Mataura -46.1927  168.8643     42.48        96         100
# 9         Pudozh  61.8099   36.5345     61.54        81          96
#
#    Wind Speed Country Current Description
# 0        7.85      ZA           clear sky
# 1       13.67      PF          light rain
# 2       14.97      SJ       broken clouds
# 3        9.22      GD       broken clouds
# 4        8.01      EC          light rain
# 5        3.00      US       moderate rain
# 6       11.59      ID     overcast clouds
# 7        1.01      US           clear sky
# 8        3.24      NZ     overcast clouds
# 9        2.71      RU     overcast clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred      ZA -33.5906   26.8910     55.98        81           1
# 1        Rikitea      PF -23.1203 -134.9692     67.32        77         100
# 2   Longyearbyen      SJ  78.2186   15.6401     51.64        76          75
# 3  Saint-Georges      GD  12.0564  -61.7485     80.28        83          75
# 4   Puerto Ayora      EC  -0.7393  -90.3518     68.56        98          73
# 5           Hilo      US  19.7297 -155.0900     76.28        95         100
# 6        Ternate      ID   0.8000  127.4000     79.09        85         100
# 7      Jamestown      US  42.0970  -79.2353     60.39        86           0
# 8        Mataura      NZ -46.1927  168.8643     42.48        96         100
# 9         Pudozh      RU  61.8099   36.5345     61.54        81          96
#
#    Wind Speed Current Description
# 0        7.85           clear sky
# 1       13.67          light rain
# 2       14.97       broken clouds
# 3        9.22       broken clouds
# 4        8.01          light rain
# 5        3.00       moderate rain
# 6       11.59     overcast clouds
# 7        1.01           clear sky
# 8        3.24     overcast clouds
# 9        2.71     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
