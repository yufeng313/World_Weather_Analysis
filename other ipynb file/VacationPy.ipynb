# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.4 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (8.2.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.1)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: appnope in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: decorator in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: backcall in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: stack-data in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: jupyter-client<8.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: nest-asyncio in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: fastjsonschema in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: argon2-cffi in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: jinja2 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: nbconvert in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: defusedxml in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: testpath in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: bleach in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: beautifulsoup4 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: packaging in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: webencodings in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Requirement already satisfied: asttokens in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.2.2)
# Requirement already satisfied: executing in /Users/yufengwu/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->gmaps) (0.8.3)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=2d24f2729c71a5906fecf257196950c03c0913283e1fcec800351abf527b3319
#   Stored in directory: /Users/yufengwu/Library/Caches/pip/wheels/66/ab/29/3032938612273665f0fa4d2fab4e3ecfe86480eaaa40aaee91
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter nbextension enable --py --sys-prefix gmaps
# Out:
#   Input In [6]
#     jupyter nbextension enable --py --sys-prefix gmaps
#             ^
# SyntaxError: invalid syntax

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID       City Country                 Date      Lat       Lng  \
# 0        0  Mahebourg      MU  2022-07-12 07:31:28 -20.4081   57.7000
# 1        1      Wewak      PG  2022-07-12 07:31:29  -3.5534  143.6268
# 2        2     Narsaq      GL  2022-07-12 07:31:29  60.9167  -46.0500
# 3        3       Cine      TR  2022-07-12 07:31:30  37.6117   28.0614
# 4        4      Balod      IN  2022-07-12 07:31:30  20.7300   81.2047
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     77.29        69          40       19.57
# 1     82.69        76         100        7.67
# 2     46.62        83          95        0.54
# 3     80.01        32           0        4.32
# 4     87.48        65          98        7.02

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
#heat_layer = gmaps.heatmap_layer(locations, weights=temps)
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,weights=clouds,dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations,weights=wind,dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 78
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 1         1           Wewak      PG  2022-07-12 07:31:29  -3.5534  143.6268
# 3         3            Cine      TR  2022-07-12 07:31:30  37.6117   28.0614
# 4         4           Balod      IN  2022-07-12 07:31:30  20.7300   81.2047
# 9         9       Bangkalan      ID  2022-07-12 07:31:32  -7.0455  112.7351
# 13       13  Saint-Philippe      RE  2022-07-12 07:31:33 -21.3585   55.7679
# 15       15      Baruun-Urt      MN  2022-07-12 07:31:34  46.6806  113.2792
# 18       18      Naryan-Mar      RU  2022-07-12 07:31:35  67.6713   53.0870
# 19       19          Matara      LK  2022-07-12 07:31:36   5.9485   80.5353
# 25       25            Fare      PF  2022-07-12 07:31:38 -16.7000 -151.0167
# 28       28          Carmen      MX  2022-07-12 07:31:39  18.6333  -91.8333
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      82.69        76         100        7.67
# 3      80.01        32           0        4.32
# 4      87.48        65          98        7.02
# 9      87.75        64          48        8.32
# 13     78.39        68          35       15.55
# 15     78.73        40          84        9.24
# 18     81.37        51          65        9.26
# 19     85.05        67         100       15.55
# 25     78.40        74           3        8.84
# 28     80.98        76         100       15.90

# %%
preferred_cities_df.count()
# Out:
# City_ID       152
# City          152
# Country       152
# Date          152
# Lat           152
# Lng           152
# Max Temp      152
# Humidity      152
# Cloudiness    152
# Wind Speed    152
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 1            Wewak      PG     82.69  -3.5534  143.6268
# 3             Cine      TR     80.01  37.6117   28.0614
# 4            Balod      IN     87.48  20.7300   81.2047
# 9        Bangkalan      ID     87.75  -7.0455  112.7351
# 13  Saint-Philippe      RE     78.39 -21.3585   55.7679
# 15      Baruun-Urt      MN     78.73  46.6806  113.2792
# 18      Naryan-Mar      RU     81.37  67.6713   53.0870
# 19          Matara      LK     85.05   5.9485   80.5353
# 25            Fare      PF     78.40 -16.7000 -151.0167
# 28          Carmen      MX     80.98  18.6333  -91.8333

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
  
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(25)
# Out:
#               City Country  Max Temp      Lat       Lng  \
# 1            Wewak      PG     82.69  -3.5534  143.6268
# 3             Cine      TR     80.01  37.6117   28.0614
# 4            Balod      IN     87.48  20.7300   81.2047
# 9        Bangkalan      ID     87.75  -7.0455  112.7351
# 13  Saint-Philippe      RE     78.39 -21.3585   55.7679
# 15      Baruun-Urt      MN     78.73  46.6806  113.2792
# 18      Naryan-Mar      RU     81.37  67.6713   53.0870
# 19          Matara      LK     85.05   5.9485   80.5353
# 25            Fare      PF     78.40 -16.7000 -151.0167
# 28          Carmen      MX     80.98  18.6333  -91.8333
# 29         Nazilli      TR     79.90  37.9163   28.3223
# 30           Isiro      CD     82.47   2.7739   27.6160
# 35      Alexandria      EG     80.04  31.2156   29.9553
# 36      Port Blair      IN     84.24  11.6667   92.7500
# 38          Awbari      LY     88.23  26.5921   12.7805
# 40           Pecos      US     89.31  31.4229 -103.4932
# 42      Santa Rosa      PH     84.18  14.3122  121.1114
# 43           Kapaa      US     78.78  22.0752 -159.3190
# 46           Seoul      KR     85.60  37.5683  126.9778
# 54         Kavieng      PG     83.73  -2.5744  150.7967
# 62          Teknaf      BD     81.82  20.8624   92.3058
# 63      Butaritari      KI     81.50   3.0707  172.7902
# 65        Okmulgee      US     79.00  35.6234  -95.9605
# 69     Finschhafen      PG     80.96  -6.6024  147.8681
# 71        Balkhash      KZ     88.41  46.8440   74.9804
#
#                                            Hotel Name
# 1                             In Wewak Boutique Hotel
# 3                                       Otel Alabanda
# 4                                         CJM Bunglow
# 9                 SPOT ON 2591 Griya Demangan Syariah
# 13                       Chambres d'hôte "La Trinité"
# 15                             Ахмадын амралт сувилал
# 18                                        Hostel Agat
# 19                             Amaloh Boutique Resort
# 25                      Maitai Lapita Village Huahine
# 28                                    Hotel Lossandes
# 29                                         Gül Palast
# 30                              Guest House Hewa Bora
# 35                                  Royal Crown Hotel
# 36  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 38                                        فندق أوباري
# 40               Knights Inn & Suites Pecos Northeast
# 42                         Erlyn’s Sta Rosa City Home
# 43                Sheraton Kauai Coconut Beach Resort
# 46                                  Lotte Hotel Seoul
# 54                                Nusa Island Retreat
# 62                                Forestry Guesthouse
# 63                                 Isles Sunset Lodge
# 65  Holiday Inn Express & Suites Okmulgee, an IHG ...
# 69                                 Cossam Guest House
# 71                                             Family

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
